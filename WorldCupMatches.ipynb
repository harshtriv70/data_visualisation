# %% [markdown]
# <a href="https://colab.research.google.com/github/harshtriv70/data_visualisation/blob/main/WorldCupMatches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("/content/WorldCupMatches.csv")
df = pd.DataFrame(data)

# %%
#1.data analysis section
#i) printing no of rows and columns
print(f"Number of Rows: {df.shape[0]}")     #shape function gives thd dimensions of the DataFrame ,
print(f"Number of Columns: {df.shape[1]}")  #it returns tuple where first element is no of rows and second is no of colunms
# Out:
# Number of Rows: 4572
# Number of Columns: 20

# %%
#ii) Print Each Column Name
print("Column Names:\n")
print(df.columns)
# Out:
# Column Names:
#
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
#iii) Print Specific Range Using Slicing
print("printing rows 10 to 20\n")
print(df.iloc[10:21])
# Out:
# printing rows 10 to 20
#
#       Year              Datetime              Stage                  Stadium  \
# 10  1930.0  19 Jul 1930 - 15:00             Group 1       Estadio Centenario
# 11  1930.0  20 Jul 1930 - 13:00             Group 2       Estadio Centenario
# 12  1930.0  20 Jul 1930 - 15:00             Group 4       Estadio Centenario
# 13  1930.0  21 Jul 1930 - 14:50             Group 3       Estadio Centenario
# 14  1930.0  22 Jul 1930 - 14:45             Group 1       Estadio Centenario
# 15  1930.0  26 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 16  1930.0  27 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 17  1930.0  30 Jul 1930 - 14:15               Final       Estadio Centenario
# 18  1934.0  27 May 1934 - 16:30   Preliminary round  Stadio Benito Mussolini
# 19  1934.0  27 May 1934 - 16:30   Preliminary round        Giorgio Ascarelli
# 20  1934.0  27 May 1934 - 16:30   Preliminary round                 San Siro
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# 10  Montevideo       Argentina              6.0              3.0
# 11  Montevideo          Brazil              4.0              0.0
# 12  Montevideo        Paraguay              1.0              0.0
# 13  Montevideo         Uruguay              4.0              0.0
# 14  Montevideo       Argentina              3.0              1.0
# 15  Montevideo       Argentina              6.0              1.0
# 16  Montevideo         Uruguay              6.0              1.0
# 17  Montevideo         Uruguay              4.0              2.0
# 18       Turin         Austria              3.0              2.0
# 19      Naples         Hungary              4.0              2.0
# 20       Milan     Switzerland              3.0              2.0
#
#    Away Team Name                 Win conditions  Attendance  \
# 10         Mexico                                    42100.0
# 11        Bolivia                                    25466.0
# 12        Belgium                                    12000.0
# 13        Romania                                    70022.0
# 14          Chile                                    41459.0
# 15            USA                                    72886.0
# 16     Yugoslavia                                    79867.0
# 17      Argentina                                    68346.0
# 18         France  Austria win after extra time      16000.0
# 19          Egypt                                     9000.0
# 20    Netherlands                                    33000.0
#
#     Half-time Home Goals  Half-time Away Goals                     Referee  \
# 10                   3.0                   1.0        SAUCEDO Ulises (BOL)
# 11                   1.0                   0.0         BALWAY Thomas (FRA)
# 12                   1.0                   0.0     VALLARINO Ricardo (URU)
# 13                   4.0                   0.0         REGO Gilberto (BRA)
# 14                   2.0                   1.0         LANGENUS Jean (BEL)
# 15                   1.0                   0.0         LANGENUS Jean (BEL)
# 16                   3.0                   1.0         REGO Gilberto (BRA)
# 17                   1.0                   2.0         LANGENUS Jean (BEL)
# 18                   0.0                   0.0  VAN MOORSEL Johannes (NED)
# 19                   2.0                   2.0    BARLASSINA Rinaldo (ITA)
# 20                   2.0                   1.0           EKLIND Ivan (SWE)
#
#                  Assistant 1                 Assistant 2  RoundID  MatchID  \
# 10    ALONSO Gualberto (URU)  RADULESCU Constantin (ROU)    201.0   1086.0
# 11  MATEUCCI Francisco (URU)        VALLEJO Gaspar (MEX)    201.0   1091.0
# 12         MACIAS Jose (ARG)      LOMBARDI Domingo (URU)    201.0   1089.0
# 13     WARNKEN Alberto (CHI)        SAUCEDO Ulises (BOL)    201.0   1100.0
# 14     CRISTOPHE Henry (BEL)        SAUCEDO Ulises (BOL)    201.0   1084.0
# 15      VALLEJO Gaspar (MEX)       WARNKEN Alberto (CHI)    202.0   1088.0
# 16      SAUCEDO Ulises (BOL)         BALWAY Thomas (FRA)    202.0   1101.0
# 17      SAUCEDO Ulises (BOL)       CRISTOPHE Henry (BEL)    405.0   1087.0
# 18     CAIRONI Camillo (ITA)           BAERT Louis (BEL)    204.0   1104.0
# 19    DATTILO Generoso (ITA)          SASSI Otello (ITA)    204.0   1119.0
# 20       BERANEK Alois (AUT)   BONIVENTO Ferruccio (ITA)    204.0   1133.0
#
#    Home Team Initials Away Team Initials
# 10                ARG                MEX
# 11                BRA                BOL
# 12                PAR                BEL
# 13                URU                ROU
# 14                ARG                CHI
# 15                ARG                USA
# 16                URU                YUG
# 17                URU                ARG
# 18                AUT                FRA
# 19                HUN                EGY
# 20                SUI                NED

# %%
#iv) Summarization Statistics
print("printing describe function to show Statistical data\n")  #describe provides descrpitive statisyics of DataFrame numeric columns ,
print(df.describe())                                            #including min,standard deviation etc
# Out:
# printing describe function to show Statistical data
#
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# min                0.000000              0.000000  2.010000e+02  2.500000e+01
# 25%                0.000000              0.000000  2.620000e+02  1.188750e+03
# 50%                0.000000              0.000000  3.370000e+02  2.191000e+03
# 75%                1.000000              1.000000  2.497220e+05  4.395006e+07
# max                6.000000              5.000000  9.741060e+07  3.001865e+08

# %%
#find no. of rows and columns
df.shape
# Out:
# (4572, 20)

# %%
#print each column name
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
#print specific range using slicing
df[10:20]
# Out:
#       Year              Datetime              Stage                  Stadium  \
# 10  1930.0  19 Jul 1930 - 15:00             Group 1       Estadio Centenario
# 11  1930.0  20 Jul 1930 - 13:00             Group 2       Estadio Centenario
# 12  1930.0  20 Jul 1930 - 15:00             Group 4       Estadio Centenario
# 13  1930.0  21 Jul 1930 - 14:50             Group 3       Estadio Centenario
# 14  1930.0  22 Jul 1930 - 14:45             Group 1       Estadio Centenario
# 15  1930.0  26 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 16  1930.0  27 Jul 1930 - 14:45         Semi-finals       Estadio Centenario
# 17  1930.0  30 Jul 1930 - 14:15               Final       Estadio Centenario
# 18  1934.0  27 May 1934 - 16:30   Preliminary round  Stadio Benito Mussolini
# 19  1934.0  27 May 1934 - 16:30   Preliminary round        Giorgio Ascarelli
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# 10  Montevideo       Argentina              6.0              3.0
# 11  Montevideo          Brazil              4.0              0.0
# 12  Montevideo        Paraguay              1.0              0.0
# 13  Montevideo         Uruguay              4.0              0.0
# 14  Montevideo       Argentina              3.0              1.0
# 15  Montevideo       Argentina              6.0              1.0
# 16  Montevideo         Uruguay              6.0              1.0
# 17  Montevideo         Uruguay              4.0              2.0
# 18       Turin         Austria              3.0              2.0
# 19      Naples         Hungary              4.0              2.0
#
#    Away Team Name                 Win conditions  Attendance  \
# 10         Mexico                                    42100.0
# 11        Bolivia                                    25466.0
# 12        Belgium                                    12000.0
# 13        Romania                                    70022.0
# 14          Chile                                    41459.0
# 15            USA                                    72886.0
# 16     Yugoslavia                                    79867.0
# 17      Argentina                                    68346.0
# 18         France  Austria win after extra time      16000.0
# 19          Egypt                                     9000.0
#
#     Half-time Home Goals  Half-time Away Goals                     Referee  \
# 10                   3.0                   1.0        SAUCEDO Ulises (BOL)
# 11                   1.0                   0.0         BALWAY Thomas (FRA)
# 12                   1.0                   0.0     VALLARINO Ricardo (URU)
# 13                   4.0                   0.0         REGO Gilberto (BRA)
# 14                   2.0                   1.0         LANGENUS Jean (BEL)
# 15                   1.0                   0.0         LANGENUS Jean (BEL)
# 16                   3.0                   1.0         REGO Gilberto (BRA)
# 17                   1.0                   2.0         LANGENUS Jean (BEL)
# 18                   0.0                   0.0  VAN MOORSEL Johannes (NED)
# 19                   2.0                   2.0    BARLASSINA Rinaldo (ITA)
#
#                  Assistant 1                 Assistant 2  RoundID  MatchID  \
# 10    ALONSO Gualberto (URU)  RADULESCU Constantin (ROU)    201.0   1086.0
# 11  MATEUCCI Francisco (URU)        VALLEJO Gaspar (MEX)    201.0   1091.0
# 12         MACIAS Jose (ARG)      LOMBARDI Domingo (URU)    201.0   1089.0
# 13     WARNKEN Alberto (CHI)        SAUCEDO Ulises (BOL)    201.0   1100.0
# 14     CRISTOPHE Henry (BEL)        SAUCEDO Ulises (BOL)    201.0   1084.0
# 15      VALLEJO Gaspar (MEX)       WARNKEN Alberto (CHI)    202.0   1088.0
# 16      SAUCEDO Ulises (BOL)         BALWAY Thomas (FRA)    202.0   1101.0
# 17      SAUCEDO Ulises (BOL)       CRISTOPHE Henry (BEL)    405.0   1087.0
# 18     CAIRONI Camillo (ITA)           BAERT Louis (BEL)    204.0   1104.0
# 19    DATTILO Generoso (ITA)          SASSI Otello (ITA)    204.0   1119.0
#
#    Home Team Initials Away Team Initials
# 10                ARG                MEX
# 11                BRA                BOL
# 12                PAR                BEL
# 13                URU                ROU
# 14                ARG                CHI
# 15                ARG                USA
# 16                URU                YUG
# 17                URU                ARG
# 18                AUT                FRA
# 19                HUN                EGY

# %%
#summariazation statistics
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# min                0.000000              0.000000  2.010000e+02  2.500000e+01
# 25%                0.000000              0.000000  2.620000e+02  1.188750e+03
# 50%                0.000000              0.000000  3.370000e+02  2.191000e+03
# 75%                1.000000              1.000000  2.497220e+05  4.395006e+07
# max                6.000000              5.000000  9.741060e+07  3.001865e+08

# %%
df.isnull()#The isnull() function in Pandas is used to detect missing values in a DataFrame.
# Out:
#        Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0     False     False  False    False  False           False            False
# 1     False     False  False    False  False           False            False
# 2     False     False  False    False  False           False            False
# 3     False     False  False    False  False           False            False
# 4     False     False  False    False  False           False            False
# ...     ...       ...    ...      ...    ...             ...              ...
# 4567   True      True   True     True   True            True             True
# 4568   True      True   True     True   True            True             True
# 4569   True      True   True     True   True            True             True
# 4570   True      True   True     True   True            True             True
# 4571   True      True   True     True   True            True             True
#
#       Away Team Goals  Away Team Name  Win conditions  Attendance  \
# 0               False           False           False       False
# 1               False           False           False       False
# 2               False           False           False       False
# 3               False           False           False       False
# 4               False           False           False       False
# ...               ...             ...             ...         ...
# 4567             True            True            True        True
# 4568             True            True            True        True
# 4569             True            True            True        True
# 4570             True            True            True        True
# 4571             True            True            True        True
#
#       Half-time Home Goals  Half-time Away Goals  Referee  Assistant 1  \
# 0                    False                 False    False        False
# 1                    False                 False    False        False
# 2                    False                 False    False        False
# 3                    False                 False    False        False
# 4                    False                 False    False        False
# ...                    ...                   ...      ...          ...
# 4567                  True                  True     True         True
# 4568                  True                  True     True         True
# 4569                  True                  True     True         True
# 4570                  True                  True     True         True
# 4571                  True                  True     True         True
#
#       Assistant 2  RoundID  MatchID  Home Team Initials  Away Team Initials
# 0           False    False    False               False               False
# 1           False    False    False               False               False
# 2           False    False    False               False               False
# 3           False    False    False               False               False
# 4           False    False    False               False               False
# ...           ...      ...      ...                 ...                 ...
# 4567         True     True     True                True                True
# 4568         True     True     True                True                True
# 4569         True     True     True                True                True
# 4570         True     True     True                True                True
# 4571         True     True     True                True                True
#
# [4572 rows x 20 columns]

# %%
df.isnull().sum()    #isnull().sum(), calculates the sum of missing values for each column in the DataFrame.
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
# Replace Missing Numerical Values with Mean or Median
# For numerical columns, replace missing values with mean

df.fillna(df["Home Team Goals"].mean(), inplace=True)

# you can use median function als0
df.fillna(df["Home Team Goals"].median(), inplace=True)

df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
#using cor() function
numerical_df=df.select_dtypes(include="number")
corr_matrix = numerical_df.corr()
print(corr_matrix)
# Out:
#                           Year  Home Team Goals  Away Team Goals  Attendance  \
# Year                  1.000000        -0.004782        -0.546830    0.867143
# Home Team Goals      -0.004782         1.000000         0.010437   -0.059036
# Away Team Goals      -0.546830         0.010437         1.000000   -0.486290
# Attendance            0.867143        -0.059036        -0.486290    1.000000
# Half-time Home Goals -0.730185         0.500341         0.394949   -0.671906
# Half-time Away Goals -0.874563        -0.004618         0.760352   -0.765212
# RoundID               0.336511        -0.103813        -0.186304    0.321160
# MatchID               0.453293        -0.175498        -0.182443    0.454889
#
#                       Half-time Home Goals  Half-time Away Goals   RoundID  \
# Year                             -0.730185             -0.874563  0.336511
# Home Team Goals                   0.500341             -0.004618 -0.103813
# Away Team Goals                   0.394949              0.760352 -0.186304
# Attendance                       -0.671906             -0.765212  0.321160
# Half-time Home Goals              1.000000              0.643992 -0.277735
# Half-time Away Goals              0.643992              1.000000 -0.285364
# RoundID                          -0.277735             -0.285364  1.000000
# MatchID                          -0.426725             -0.364520  0.208736
#
#                        MatchID
# Year                  0.453293
# Home Team Goals      -0.175498
# Away Team Goals      -0.182443
# Attendance            0.454889
# Half-time Home Goals -0.426725
# Half-time Away Goals -0.364520
# RoundID               0.208736
# MatchID               1.000000

# %%
## Data Visualization

#i) Pairplot
sns.pairplot(df)
plt.title("pairplot")
plt.show()

# %%
#ii) Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title("boxplot")
plt.legend(df)
plt.show()

# %%
#iii) Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("heatmap")
plt.show()

# %%
#iv) Barplot
plt.figure(figsize=(10, 6))
sns.barplot(x='Home Team Goals', y='Away Team Goals', data=df)
plt.title("barplot")
plt.xlabel='Home Team Goals'
plt.ylabel='Away Team Goals'
plt.show()

# %%
#v) Histogram
plt.figure(figsize=(10, 6))
df['Away Team Goals'].hist(bins=20)
plt.title("hitogram")
plt.show()

# %%
#vi) Distribution Plot
plt.figure(figsize=(10, 6))
sns.displot(df['Home Team Goals'])
plt.title("distribution plot")
plt.show()

# %%
#vii) Scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Home Team Goals', y='Away Team Goals', data=df)
plt.title("scattter plot")
plt.show()
